# %% [markdown]
# # Q-Q dispersive 下 cross-Kerr 与 g 关系验证
#
# BAQIS 结构：
# Qubit-Qubit

# %%
# 导入必要的包
import pyEPR as epr
import numpy as np

# %%
# 与 Ansys 建立连接
pinfo = epr.ProjectInfo(project_path = r'C:\Users\admin\Desktop\QEDA\量子院QCQ\AnsysProject',  # project 所在的文件夹
                        project_name = r'QCQ_BAQIS',  # project 名字
                        design_name  = r'QQ')  # design 名字
# Out:
# INFO 10:45AM [connect_project]: Connecting to Ansys Desktop API...
# INFO 10:45AM [load_ansys_project]: 	File path to HFSS project found.
# INFO 10:45AM [load_ansys_project]: 	Opened Ansys App
# INFO 10:45AM [load_ansys_project]: 	Opened Ansys Desktop v2021.2.0
# INFO 10:45AM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/admin/Desktop/QEDA/量子院QCQ/AnsysProject/
# 	Project:   QCQ_BAQIS
# INFO 10:45AM [connect_design]: 	Opened active design
# 	Design:    QQ [Solution type: Eigenmode]
# INFO 10:45AM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 10:45AM [connect]: 	Connected to project "QCQ_BAQIS" and design "QQ" 😀

# %%
# 指定 juntion 的信息
pinfo.junctions['Q1'] = {'Lj_variable':'Lj1', 'rect':'JJ1', 'line': 'JJ1_line', 'Cj_variable':'Cj'}
pinfo.junctions['Q2'] = {'Lj_variable':'Lj2', 'rect':'JJ2', 'line': 'JJ2_line', 'Cj_variable':'Cj'}
pinfo.validate_junction_info() # Check that valid names of variables and objects have been supplied.

# %%
# 指定耗散部分
pinfo.dissipative['dielectrics_bulk'] = ['Box1']  # []中填写衬底等非理想介质体的名称

# %%
# 开始微波仿真分析(先手动仿真完再运行这一步)
eprd = epr.DistributedAnalysis(pinfo)
# swp_var = 'Lj_Q2' # Sweep variable from optimetric analysis that should be used on the x axis for the frequency plot
# eprd.quick_plot_frequencies(swp_var) # plot the solved frequencies before the analysis
eprd.hfss_report_full_convergence() # report convergen
eprd.do_EPR_analysis()
# Out:
# INFO 11:16AM [hfss_report_full_convergence]: Creating report for variation 0
# Design "QQ" info:
# 	# eigenmodes    2
# 	# variations    7
# INFO 11:16AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ\hfss_eig_f_convergence.csv
# INFO 11:16AM [hfss_report_full_convergence]: Creating report for variation 1
# INFO 11:17AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ\hfss_eig_f_convergence.csv
# INFO 11:17AM [hfss_report_full_convergence]: Creating report for variation 2
# INFO 11:17AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ\hfss_eig_f_convergence.csv
# INFO 11:17AM [hfss_report_full_convergence]: Creating report for variation 3
# INFO 11:17AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ\hfss_eig_f_convergence.csv
# INFO 11:17AM [hfss_report_full_convergence]: Creating report for variation 4
# INFO 11:17AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ\hfss_eig_f_convergence.csv
# INFO 11:17AM [hfss_report_full_convergence]: Creating report for variation 5
# INFO 11:17AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ\hfss_eig_f_convergence.csv
# INFO 11:17AM [hfss_report_full_convergence]: Creating report for variation 6
# INFO 11:17AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ\hfss_eig_f_convergence.csv
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 0  [1/7]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 5.02 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.1%  8.174e-25 7.386e-27
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.05%
# 	Q1              0.990711  (+)        0.0196924
# 		Energy fraction (Lj over Lj&Cj)= 99.02%
# 	Q2              4.72171e-06  (+)        4.69268e-08
# 		(U_tot_cap-U_tot_ind)/mean=0.99%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.9017947981209895
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 7.19 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.1%  7.478e-25 1.406e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 96.08%
# 	Q1              4.09363e-06  (+)        1.66871e-07
# 		Energy fraction (Lj over Lj&Cj)= 98.00%
# 	Q2              0.980628  (+)        0.019987
# 		(U_tot_cap-U_tot_ind)/mean=1.02%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9040017386709581
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 1  [2/7]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 5.58 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.9%  7.556e-25 8.303e-27
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.07%
# 	Q1              0.988632  (+)        0.0194103
# 		Energy fraction (Lj over Lj&Cj)= 98.79%
# 	Q2              9.15295e-06  (+)        1.12315e-07
# 		(U_tot_cap-U_tot_ind)/mean=0.98%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.8996985065805465
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 7.15 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.1%  1.208e-24 2.254e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 96.87%
# 	Q1              8.16826e-06  (+)        2.63834e-07
# 		Energy fraction (Lj over Lj&Cj)= 98.02%
# 	Q2              0.980775  (+)        0.0197993
# 		(U_tot_cap-U_tot_ind)/mean=1.01%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9036970897154746
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 2  [3/7]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 4.51 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.3%  1.953e-24 1.353e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.11%
# 	Q1              0.992831  (+)        0.0191019
# 		Energy fraction (Lj over Lj&Cj)= 99.20%
# 	Q2              2.63158e-06  (+)        2.10964e-08
# 		(U_tot_cap-U_tot_ind)/mean=0.96%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.891841463513315
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 7.16 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.1%  7.927e-25 1.471e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 95.37%
# 	Q1              2.25716e-06  (+)        1.09515e-07
# 		Energy fraction (Lj over Lj&Cj)= 98.02%
# 	Q2              0.980885  (+)        0.0198298
# 		(U_tot_cap-U_tot_ind)/mean=1.01%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9031504798515602
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 3  [4/7]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 4.22 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.4%  1.089e-24 7.029e-27
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.07%
# 	Q1              0.993076  (+)        0.0195347
# 		Energy fraction (Lj over Lj&Cj)= 99.30%
# 	Q2              2.07473e-06  (+)        1.45757e-08
# 		(U_tot_cap-U_tot_ind)/mean=0.99%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.9011066479414418
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 7.19 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.1%   7.23e-25 1.362e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 94.59%
# 	Q1              1.72655e-06  (+)        9.87583e-08
# 		Energy fraction (Lj over Lj&Cj)= 98.00%
# 	Q2              0.980597  (+)        0.0200321
# 		(U_tot_cap-U_tot_ind)/mean=1.02%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9039109965081512
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 4  [5/7]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 3.93 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.5%  1.182e-24 6.354e-27
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.08%
# 	Q1              0.994394  (+)        0.0194162
# 		Energy fraction (Lj over Lj&Cj)= 99.39%
# 	Q2              1.62554e-06  (+)        9.91866e-09
# 		(U_tot_cap-U_tot_ind)/mean=0.97%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.8970569951175983
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 7.16 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.1%  8.593e-25 1.663e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 93.92%
# 	Q1              1.34676e-06  (+)        8.71361e-08
# 		Energy fraction (Lj over Lj&Cj)= 98.02%
# 	Q2              0.980829  (+)        0.0198313
# 		(U_tot_cap-U_tot_ind)/mean=0.97%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9034511938686518
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 5  [6/7]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 3.70 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.5%  1.279e-24 6.275e-27
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.09%
# 	Q1              0.994902  (+)        0.019369
# 		Energy fraction (Lj over Lj&Cj)= 99.46%
# 	Q2              1.27102e-06  (+)        6.87348e-09
# 		(U_tot_cap-U_tot_ind)/mean=0.97%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.8997838536819822
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 7.16 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.1%  7.939e-25 1.482e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 93.21%
# 	Q1              1.04644e-06  (+)        7.62765e-08
# 		Energy fraction (Lj over Lj&Cj)= 98.02%
# 	Q2              0.980769  (+)        0.0198582
# 		(U_tot_cap-U_tot_ind)/mean=1.01%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9034157350816397
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 6  [7/7]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 3.47 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.6%  2.435e-24 1.008e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.13%
# 	Q1              0.995723  (+)        0.018933
# 		Energy fraction (Lj over Lj&Cj)= 99.53%
# 	Q2              1.07906e-06  (+)        5.12942e-09
# 		(U_tot_cap-U_tot_ind)/mean=0.94%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.8879279465341077
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 7.18 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.1%  7.927e-25 1.525e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 92.47%
# 	Q1              8.75616e-07  (+)        7.12839e-08
# 		Energy fraction (Lj over Lj&Cj)= 98.01%
# 	Q2              0.980428  (+)        0.0199542
# 		(U_tot_cap-U_tot_ind)/mean=1.00%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9039265480912556
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# ANALYSIS DONE. Data saved to:
#
# C:\data-pyEPR\QCQ_BAQIS\QQ\2022-04-12 11-16-55.npz
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# (WindowsPath('C:/data-pyEPR/QCQ_BAQIS/QQ/2022-04-12 11-16-55.npz'),
#  ['0', '1', '2', '3', '4', '5', '6'])

# %%
# 进行EPR分析
epra = epr.QuantumAnalysis(eprd.data_filename)
epra.analyze_all_variations(cos_trunc = 8, fock_trunc = 7)
# Out:
# 	 Differences in variations:
# variation     0    1     2     3     4     5     6
# _Lj1       10nH  8nH  12nH  14nH  16nH  18nH  20nH
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 0
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.020038
# 1    1.020767
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0   True  False
# 1  False   True
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj1    10nH
# Name: 0, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.971578  0.000005
# 1  0.000004  0.961412
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#       0.99  4.6e-06
#      4e-06     0.98
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        189  0.00345
#    0.00345      190
#
# *** Chi matrix ND (MHz)
#        206  0.00427
#    0.00427      202
#
# *** Frequencies O1 PT (MHz)
# 0    4828.345924
# 1    6995.134056
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    4820.598934
# 1    6989.872935
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 1
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.019899
# 1    1.020571
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0   True  False
# 1  False   True
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj1    8nH
# Name: 1, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.969807  0.000009
# 1  0.000008  0.961733
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#       0.99    9e-06
#      8e-06     0.98
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        186  0.00655
#    0.00655      188
#
# *** Chi matrix ND (MHz)
#        200  0.00856
#    0.00856      200
#
# *** Frequencies O1 PT (MHz)
# 0    5389.140391
# 1    6962.538924
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    5382.477149
# 1    6957.350911
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 2
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.019412
# 1    1.020591
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0   True  False
# 1  False   True
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj1    12nH
# Name: 2, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.974221  0.000003
# 1  0.000002  0.961812
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#       0.99  2.6e-06
#    2.2e-06     0.98
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        184  0.00193
#    0.00193      189
#
# *** Chi matrix ND (MHz)
#        201  0.00235
#    0.00235      200
#
# *** Frequencies O1 PT (MHz)
# 0    4322.462154
# 1    6967.333987
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    4314.229763
# 1    6962.131550
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 3
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.020075
# 1    1.020807
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0   True  False
# 1  False   True
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj1    14nH
# Name: 3, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.974048  0.000002
# 1  0.000002  0.961339
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#       0.99    2e-06
#    1.7e-06     0.98
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        188  0.00156
#    0.00156      191
#
# *** Chi matrix ND (MHz)
#        208   0.0019
#     0.0019      202
#
# *** Frequencies O1 PT (MHz)
# 0    4030.368309
# 1    7002.932967
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    4021.065655
# 1    6997.654367
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 4
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.019704
# 1    1.019847
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0   True  False
# 1  False   True
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj1    16nH
# Name: 4, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.975455  0.000002
# 1  0.000001  0.961756
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#       0.99  1.6e-06
#    1.3e-06     0.98
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        187  0.00124
#    0.00124      188
#
# *** Chi matrix ND (MHz)
#        208  0.00152
#    0.00152      200
#
# *** Frequencies O1 PT (MHz)
# 0    3744.307710
# 1    6968.089173
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    3734.343263
# 1    6962.907116
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 5
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.019611
# 1    1.020627
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0   True  False
# 1  False   True
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj1    18nH
# Name: 5, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.975998  0.000001
# 1  0.000001  0.961672
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#          1  1.2e-06
#      1e-06     0.98
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        187 0.000993
#   0.000993      189
#
# *** Chi matrix ND (MHz)
#        209  0.00122
#    0.00122      200
#
# *** Frequencies O1 PT (MHz)
# 0    3514.388902
# 1    6972.625882
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    3503.765496
# 1    6967.414097
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 6
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.019114
# 1    1.020502
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0   True  False
# 1  False   True
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj1    20nH
# Name: 6, dtype: object
# *** P (participation matrix, not normlz.)
#              Q1        Q2
# 0  9.772208e-01  0.000001
# 1  8.584853e-07  0.961247
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#          1  1.1e-06
#    8.6e-07     0.98
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        183 0.000849
#   0.000849      190
#
# *** Chi matrix ND (MHz)
#        205  0.00106
#    0.00106      201
#
# *** Frequencies O1 PT (MHz)
# 0    3287.362059
# 1    6990.395547
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    3276.450749
# 1    6985.157867
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
# OrderedDict([('0',
#               OrderedDict([('f_0', 0    5017.427494
#                             1    7185.252857
#                             Name: 0, dtype: float64),
#                            ('f_1',
#                             0    4828.345924
#                             1    6995.134056
#                             dtype: float64),
#                            ('f_ND',
#                             0    4820.598934
#                             1    6989.872935
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  189.079847    0.003446
#                             1    0.003446  190.117079),
#                            ('chi_ND',
#                                         0           1
#                             0  205.694889    0.004273
#                             1    0.004273  201.633290),
#                            ('ZPF',
#                             array([[0.39000029, 0.0005961 ],
#                                    [0.00093919, 0.32839868]])),
#                            ('Pm_normed',
#                             array([[9.91047036e-01, 4.63052312e-06],
#                                    [4.01340881e-06, 9.81377866e-01]])),
#                            ('Pm_raw',
#                             0    0.971578
#                             1    0.000004
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.020038
#                             1    1.020767
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.498557
#                             1    0.490717
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Cj        0
#                             _Lj1    10nH
#                             _Lj2     5nH
#                             Name: 0, dtype: object),
#                            ('Ljs',
#                             Q1    1.000000e-08
#                             Q2    5.000000e-09
#                             Name: 0, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 0, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 0, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('1',
#               OrderedDict([('f_0', 0    5575.175374
#                             1    7150.898937
#                             Name: 1, dtype: float64),
#                            ('f_1',
#                             0    5389.140391
#                             1    6962.538924
#                             dtype: float64),
#                            ('f_ND',
#                             0    5382.477149
#                             1    6957.350911
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  186.031708    0.006551
#                             1    0.006551  188.356737),
#                            ('chi_ND',
#                                         0           1
#                             0  200.442615    0.008556
#                             1    0.008556  199.714181),
#                            ('ZPF',
#                             array([[0.36734392, 0.00087498],
#                                    [0.00118389, 0.32763585]])),
#                            ('Pm_normed',
#                             array([[9.89105713e-01, 8.97867433e-06],
#                                    [8.00967358e-06, 9.81516686e-01]])),
#                            ('Pm_raw',
#                             0    0.969807
#                             1    0.000008
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.019899
#                             1    1.020571
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.495264
#                             1    0.490655
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Cj       0
#                             _Lj1    8nH
#                             _Lj2    5nH
#                             Name: 1, dtype: object),
#                            ('Ljs',
#                             Q1    8.000000e-09
#                             Q2    5.000000e-09
#                             Name: 1, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 1, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 1, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('2',
#               OrderedDict([('f_0', 0    4506.253064
#                             1    7155.998904
#                             Name: 2, dtype: float64),
#                            ('f_1',
#                             0    4322.462154
#                             1    6967.333987
#                             dtype: float64),
#                            ('f_ND',
#                             0    4314.229763
#                             1    6962.131550
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  183.789947    0.001926
#                             1    0.001926  188.663954),
#                            ('chi_ND',
#                                         0           1
#                             0  201.332090    0.002351
#                             1    0.002351  200.053647),
#                            ('ZPF',
#                             array([[0.40530258, 0.00042186],
#                                    [0.00076247, 0.32776936]])),
#                            ('Pm_normed',
#                             array([[9.93133030e-01, 2.58225873e-06],
#                                    [2.21327261e-06, 9.81616725e-01]])),
#                            ('Pm_raw',
#                             0    0.974221
#                             1    0.000002
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.019412
#                             1    1.020591
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.498512
#                             1    0.490912
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Cj        0
#                             _Lj1    12nH
#                             _Lj2     5nH
#                             Name: 2, dtype: object),
#                            ('Ljs',
#                             Q1    1.200000e-08
#                             Q2    5.000000e-09
#                             Name: 2, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 2, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 2, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('3',
#               OrderedDict([('f_0', 0    4218.454408
#                             1    7193.471754
#                             Name: 3, dtype: float64),
#                            ('f_1',
#                             0    4030.368309
#                             1    7002.932967
#                             dtype: float64),
#                            ('f_ND',
#                             0    4021.065655
#                             1    6997.654367
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  188.085321    0.001556
#                             1    0.001556  190.538009),
#                            ('chi_ND',
#                                         0           1
#                             0  207.738744    0.001900
#                             1    0.001900  202.092313),
#                            ('ZPF',
#                             array([[4.23666724e-01, 3.62342357e-04],
#                                    [7.22092861e-04, 3.28580304e-01]])),
#                            ('Pm_normed',
#                             array([[9.93602840e-01, 2.03498099e-06],
#                                    [1.69264169e-06, 9.81341166e-01]])),
#                            ('Pm_raw',
#                             0    0.974048
#                             1    0.000002
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.020075
#                             1    1.020807
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.492916
#                             1    0.490907
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Cj        0
#                             _Lj1    14nH
#                             _Lj2     5nH
#                             Name: 3, dtype: object),
#                            ('Ljs',
#                             Q1    1.400000e-08
#                             Q2    5.000000e-09
#                             Name: 3, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 3, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 3, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('4',
#               OrderedDict([('f_0', 0    3931.408011
#                             1    7156.482194
#                             Name: 4, dtype: float64),
#                            ('f_1',
#                             0    3744.307710
#                             1    6968.089173
#                             dtype: float64),
#                            ('f_ND',
#                             0    3734.343263
#                             1    6962.907116
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  187.099681    0.001241
#                             1    0.001241  188.392400),
#                            ('chi_ND',
#                                         0           1
#                             0  207.999844    0.001516
#                             1    0.001516  199.738538),
#                            ('ZPF',
#                             array([[4.37473628e-01, 3.09641415e-04],
#                                    [6.80091758e-04, 3.27651353e-01]])),
#                            ('Pm_normed',
#                             array([[9.94674911e-01, 1.59457692e-06],
#                                    [1.32056856e-06, 9.80843780e-01]])),
#                            ('Pm_raw',
#                             0    0.975455
#                             1    0.000001
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.019704
#                             1    1.019847
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.498897
#                             1    0.509358
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Cj        0
#                             _Lj1    16nH
#                             _Lj2     5nH
#                             Name: 4, dtype: object),
#                            ('Ljs',
#                             Q1    1.600000e-08
#                             Q2    5.000000e-09
#                             Name: 4, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 4, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 4, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('5',
#               OrderedDict([('f_0', 0    3701.112373
#                             1    7161.540990
#                             Name: 5, dtype: float64),
#                            ('f_1',
#                             0    3514.388902
#                             1    6972.625882
#                             dtype: float64),
#                            ('f_ND',
#                             0    3503.765496
#                             1    6967.414097
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  186.722975    0.000993
#                             1    0.000993  188.914612),
#                            ('chi_ND',
#                                         0           1
#                             0  208.843173    0.001223
#                             1    0.001223  200.324670),
#                            ('ZPF',
#                             array([[4.50319949e-01, 2.65667781e-04],
#                                    [6.36069641e-04, 3.27878175e-01]])),
#                            ('Pm_normed',
#                             array([[9.95137530e-01, 1.24686953e-06],
#                                    [1.02606732e-06, 9.81508447e-01]])),
#                            ('Pm_raw',
#                             0    0.975998
#                             1    0.000001
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.019611
#                             1    1.020627
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.499914
#                             1    0.490788
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Cj        0
#                             _Lj1    18nH
#                             _Lj2     5nH
#                             Name: 5, dtype: object),
#                            ('Ljs',
#                             Q1    1.800000e-08
#                             Q2    5.000000e-09
#                             Name: 5, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 5, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 5, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('6',
#               OrderedDict([('f_0', 0    3470.01159
#                             1    7180.07531
#                             Name: 6, dtype: float64),
#                            ('f_1',
#                             0    3287.362059
#                             1    6990.395547
#                             dtype: float64),
#                            ('f_ND',
#                             0    3276.450749
#                             1    6985.157867
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  182.649106    0.000849
#                             1    0.000849  189.679339),
#                            ('chi_ND',
#                                         0           1
#                             0  205.236922    0.001063
#                             1    0.001063  201.145570),
#                            ('ZPF',
#                             array([[4.59796337e-01, 2.37070805e-04],
#                                    [6.14077467e-04, 3.28209485e-01]])),
#                            ('Pm_normed',
#                             array([[9.95899703e-01, 1.05901163e-06],
#                                    [8.58485250e-07, 9.80954270e-01]])),
#                            ('Pm_raw',
#                             0    9.772208e-01
#                             1    8.584853e-07
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.019114
#                             1    1.020502
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.501027
#                             1    0.496425
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Cj        0
#                             _Lj1    20nH
#                             _Lj2     5nH
#                             Name: 6, dtype: object),
#                            ('Ljs',
#                             Q1    2.000000e-08
#                             Q2    5.000000e-09
#                             Name: 6, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 6, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 6, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)]))])

# %% [markdown]
# ## 进行数据分析

# %% [markdown]
# 根据推导结果，cross-Kerr 与 g 的关系为
# $$
# \chi = 2\frac{g^2}{\Delta^2}(E_{C1} + E_{C2})
# $$
# 因此，耦合强度，
# $$
# g = \sqrt{\frac{\Delta^2 \chi}{2(E_{C1}+E_{C2})}}
# $$

# %%
chi = np.array([0.00655, 0.00345, 0.001926, 0.001556, 0.001241, 0.000993, 0.000849])
freq1 = np.array([5575.175374, 5017.427494, 4506.253064, 4218.454408, 3931.408011, 3701.112373, 3470.01159])
freq2 = np.array([7150.898937, 7185.252857, 7155.998904, 7193.471754, 7156.482194, 7161.540990, 7180.07531])
alpha1 = np.array([186, 189, 183.789947, 188.085321, 187.099681, 186.722975, 182.649106])
alpha2 = np.array([188, 190, 188.663954, 190.538009, 188.392400, 188.914612, 189.679339])

# %%
delta = np.abs(freq1 - freq2)
g_disp = np.sqrt(((delta ** 2) * chi) / (2 * (alpha1 + alpha2)))

# %%
g_disp
# Out:
# array([4.6628332 , 4.62486689, 4.2607014 , 4.26457361, 4.14581779,
#        3.97836843, 3.96147672])

# %%
g_reson = g_disp / np.sqrt(freq1 * freq2) * np.sqrt(4961 * 4926)

# %%
g_reson
# Out:
# array([3.65066608, 3.80775919, 3.7091124 , 3.82702661, 3.86383143,
#        3.82003587, 3.92336725])

# %% [markdown]
# ### 错误公式验证

# %% [markdown]
# 错误公式，
# $$
# \chi = \frac{g^2}{\Delta}
# $$
# 因此，耦合强度
# $$
# g = \sqrt{\chi \Delta}
# $$

# %%
delta = np.abs(freq1 - freq2)
g_disp_error = np.sqrt(chi * delta)

# %%
g_disp_error
# Out:
# array([3.21262966, 2.73477559, 2.25907293, 2.15154061, 2.00057918,
#        1.85370052, 1.77478001])

# %%
g_reson_error = g_disp_error / np.sqrt(freq1 * freq2) * freq2

# %%
g_reson_error
# Out:
# array([3.63841068, 3.27266965, 2.84680418, 2.80958476, 2.69917774,
#        2.57855665, 2.55295739])

# %% [markdown]
# ### Q3D + 等效电路检验

# %%
C_1g = 0.08946
C_2g = 0.08923
C_12 = 0.00013

# %% [markdown]
# 等效电路 Q-Q 结构耦合强度计算公式
# $$
# g = \frac{1}{2} \frac{C_{12}}{\sqrt{(C_{1g}+C_{12})(C_{2g}+C_{12})}}\sqrt{\omega_1 \omega_2}
# $$

# %%
# 耦合强度除掉频率项后的无量纲部分
g_effCirc_dimless =  0.5 * C_12 / np.sqrt((C_1g + C_12) * (C_2g + C_12))

# %%
g_effCirc_dimless
# Out:
# 0.0007264605050334611

# %%
# 等效电路下的耦合强度
g_effCirc = g_effCirc_dimless * np.sqrt(4961 * 4926)
g_effCirc
# Out:
# 3.5912350044354158
