# %% [markdown]
# # Q-Q共振 EPR耦合强度与NormalMode的关系
#
# 1. 仿真 QQ 共振下的频率
# 2. 利用 Normal Mode 方法计算耦合强度
# 3. 利用 EPR 方法计算耦合强度
#
# 版图：Qubit-Qubit (BAQIS)

# %%
# 导入必要的包
import pyEPR as epr
import numpy as np

# %%
# 与 Ansys 建立连接
pinfo = epr.ProjectInfo(project_path = r'C:\Users\admin\Desktop\QEDA\量子院QCQ\AnsysProject',  # project 所在的文件夹
                        project_name = r'QCQ_BAQIS',  # project 名字
                        design_name  = r'QQ_1')  # design 名字
# Out:
# INFO 04:44PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 04:44PM [load_ansys_project]: 	File path to HFSS project found.
# INFO 04:44PM [load_ansys_project]: 	Opened Ansys App
# INFO 04:44PM [load_ansys_project]: 	Opened Ansys Desktop v2021.2.0
# INFO 04:44PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/admin/Desktop/QEDA/量子院QCQ/AnsysProject/
# 	Project:   QCQ_BAQIS
# INFO 04:44PM [connect_design]: 	Opened active design
# 	Design:    QQ_1 [Solution type: Eigenmode]
# INFO 04:44PM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 04:44PM [connect]: 	Connected to project "QCQ_BAQIS" and design "QQ_1" 😀

# %%
# 指定 juntion 的信息
pinfo.junctions['Q1'] = {'Lj_variable':'Lj1', 'rect':'JJ1', 'line': 'JJ1_line', 'Cj_variable':'Cj'}
pinfo.junctions['Q2'] = {'Lj_variable':'Lj2', 'rect':'JJ2', 'line': 'JJ2_line', 'Cj_variable':'Cj'}
pinfo.validate_junction_info() # Check that valid names of variables and objects have been supplied.

# %%
# 指定耗散部分
pinfo.dissipative['dielectrics_bulk'] = ['Box1']  # []中填写衬底等非理想介质体的名称

# %%
# 开始微波仿真分析(先手动仿真完再运行这一步)
eprd = epr.DistributedAnalysis(pinfo)
# swp_var = 'Lj_Q2' # Sweep variable from optimetric analysis that should be used on the x axis for the frequency plot
# eprd.quick_plot_frequencies(swp_var) # plot the solved frequencies before the analysis
eprd.hfss_report_full_convergence() # report convergen
eprd.do_EPR_analysis()
# Out:
# INFO 06:21PM [hfss_report_full_convergence]: Creating report for variation 0
# Design "QQ_1" info:
# 	# eigenmodes    2
# 	# variations    5
# INFO 06:21PM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ_1\hfss_eig_f_convergence.csv
# INFO 06:21PM [hfss_report_full_convergence]: Creating report for variation 1
# INFO 06:21PM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ_1\hfss_eig_f_convergence.csv
# INFO 06:21PM [hfss_report_full_convergence]: Creating report for variation 2
# INFO 06:21PM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ_1\hfss_eig_f_convergence.csv
# INFO 06:21PM [hfss_report_full_convergence]: Creating report for variation 3
# INFO 06:21PM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QQ_1\hfss_eig_f_convergence.csv
# INFO 06:21PM [hfss_report_full_convergence]: Creating report for variation 4
# ...

# %%
# 进行EPR分析
epra = epr.QuantumAnalysis(eprd.data_filename)
epra.analyze_all_variations(cos_trunc = 8, fock_trunc = 7)
# Out:
# 	 Differences in variations:
# variation     0    1    2     3     4
# _Lj1       14nH  5nH  8nH  10nH  12nH
# _Lj2       14nH  5nH  8nH  10nH  12nH
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 0
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.022271
# 1    1.022365
# dtype: float64
#
# Pm_norm idx =
#      Q1    Q2
# 0  True  True
# 1  True  True
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# ...

# %% [markdown]
# ## 进行数据分析

# %% [markdown]
# a

# %%
#Lj=[5, 8, 12, 14]nH
freq1 = np.array([7356.247158, 5833.205901, 4775.055980, 4424.191514, ])
freq2 = np.array([7367.728789, 5842.841051, 4783.214342, 4431.791297,])
p11 = np.array([0.524986, 0.523666, 0.526714, 0.496707, ])
p12 = np.array([0.433975, 0.442450, 0.443738, 0.474724, ])
p21 = np.array([0.433813, 0.442128, 0.443336, 0.475077, ])
p22 = np.array([0.524604, 0.523646, 0.526897, 0.496091, ])

# %%
# Normal Mode 方法求耦合强度
g_nm = np.abs(freq1-freq2)/2
g_nm
# Out:
# array([5.7408155, 4.817575 , 4.079181 , 3.7998915])

# %%
#EPR 方法
EPR_term1 = p11 ** 2 + p12 ** 2 
EPR_term2 = p21 ** 2 + p22 ** 2
EPR_term3 = p11 * p21 + p12 * p22

EPR_param = (freq1 * freq2) * EPR_term3 / (freq1 ** 2 * EPR_term1 + freq2 ** 2 * EPR_term2)
EPR_param
# Out:
# array([0.49108942, 0.49295391, 0.49268929, 0.49950983])

# %%
p_eff = EPR_term3 / (EPR_term1 + EPR_term2)
p_eff
# Out:
# array([0.49108957, 0.49295432, 0.49268986, 0.49951032])

# %%
g_EPR = np.sqrt((freq1 - freq2)**2 * EPR_param)
g_EPR
# Out:
# array([8.04607126, 6.76490402, 5.72650352, 5.37122337])

# %%
g_EPR/np.sqrt(2)
# Out:
# array([5.68943155, 4.7835095 , 4.04924947, 3.79802847])
