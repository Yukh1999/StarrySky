# %% [markdown]
# # QCQ EPR计算耦合强度--QCQ 均dispersive
#
# BAQIS 结构：
# Qubit-Coupler-Qubit

# %%
# 导入必要的包
import pyEPR as epr
import numpy as np

# %%
# 与 Ansys 建立连接
pinfo = epr.ProjectInfo(project_path = r'C:\Users\admin\Desktop\QEDA\量子院QCQ\AnsysProject',  # project 所在的文件夹
                        project_name = r'QCQ_BAQIS',  # project 名字
                        design_name  = r'QCQ1')  # design 名字
# Out:
# INFO 05:19PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 05:19PM [load_ansys_project]: 	File path to HFSS project found.
# INFO 05:19PM [load_ansys_project]: 	Opened Ansys App
# INFO 05:19PM [load_ansys_project]: 	Opened Ansys Desktop v2021.2.0
# INFO 05:19PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/admin/Desktop/QEDA/量子院QCQ/AnsysProject/
# 	Project:   QCQ_BAQIS
# INFO 05:19PM [connect_design]: 	Opened active design
# 	Design:    QCQ1 [Solution type: Eigenmode]
# INFO 05:19PM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 05:19PM [connect]: 	Connected to project "QCQ_BAQIS" and design "QCQ1" 😀

# %%
# 指定 juntion 的信息
pinfo.junctions['Q1'] = {'Lj_variable':'Lj_Q1', 'rect':'Junc_Q1', 'line': 'Junc_Line_Q1', 'Cj_variable':'Cj'}
pinfo.junctions['Q2'] = {'Lj_variable':'Lj_Q2', 'rect':'Junc_Q2', 'line': 'Junc_Line_Q2', 'Cj_variable':'Cj'}
pinfo.junctions['Coup'] = {'Lj_variable':'Lj_C', 'rect':'Junc_C', 'line': 'Junc_Line_C', 'Cj_variable':'Cj'}
pinfo.validate_junction_info() # Check that valid names of variables and objects have been supplied.

# %%
# 指定耗散部分
pinfo.dissipative['dielectrics_bulk'] = ['Substrate']  # []中填写衬底等非理想介质体的名称

# %%
# 开始微波仿真分析(先手动仿真完再运行这一步)
eprd = epr.DistributedAnalysis(pinfo)
# swp_var = 'Lj_Q2' # Sweep variable from optimetric analysis that should be used on the x axis for the frequency plot
# eprd.quick_plot_frequencies(swp_var) # plot the solved frequencies before the analysis
eprd.hfss_report_full_convergence() # report convergen
eprd.do_EPR_analysis()
# Out:
# INFO 08:36PM [hfss_report_full_convergence]: Creating report for variation 0
# Design "QCQ1" info:
# 	# eigenmodes    3
# 	# variations    1
# INFO 08:36PM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\QCQ_BAQIS\QCQ1\hfss_eig_f_convergence.csv
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 0  [1/1]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 1.14 GHz   [1/3]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#               100.0%  6.527e-25 3.237e-28
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.98%
# 	Q1              6.66803e-06  (+)        6.89148e-08
# 		Energy fraction (Lj over Lj&Cj)= 97.97%
# 	Q2              0.998935  (+)        0.0206482
# 		Energy fraction (Lj over Lj&Cj)= 99.95%
# 	Coup            1.65529e-05  (+)        8.55379e-09
# 		(U_tot_cap-U_tot_ind)/mean=1.05%
# Calculating Qdielectric_Substrate for mode 0 (0/2)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Substrate_0 = 0.9064164797079614
#
#   Mode 1 at 1.64 GHz   [2/3]
#     Calculating ℰ_magnetic,
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
# ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.9%  2.689e-25 2.716e-28
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 97.93%
# 	Q1               0.99803  (+)        0.0210888
# 		Energy fraction (Lj over Lj&Cj)= 95.95%
# 	Q2              6.48853e-06  (+)        2.7421e-07
# 		Energy fraction (Lj over Lj&Cj)= 99.89%
# 	Coup            3.58413e-05  (+)        3.78671e-08
# 		(U_tot_cap-U_tot_ind)/mean=1.09%
# Calculating Qdielectric_Substrate for mode 1 (1/2)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Substrate_1 = 0.9074187968180387
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 2 at 7.94 GHz   [3/3]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.0%  1.544e-25 3.148e-27
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_2j   sign s_2j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 66.77%
# 	Q1              3.45172e-05  (+)        1.7178e-05
# 		Energy fraction (Lj over Lj&Cj)= 50.12%
# 	Q2              1.60649e-05  (+)        1.59899e-05
# 		Energy fraction (Lj over Lj&Cj)= 97.57%
# 	Coup            0.978187  (+)        0.0243405
# 		(U_tot_cap-U_tot_ind)/mean=1.27%
# Calculating Qdielectric_Substrate for mode 2 (2/2)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Substrate_2 = 0.9082888326222869
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# ANALYSIS DONE. Data saved to:
#
# C:\data-pyEPR\QCQ_BAQIS\QCQ1\2022-06-10 20-36-05.npz
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# (WindowsPath('C:/data-pyEPR/QCQ_BAQIS/QCQ1/2022-06-10 20-36-05.npz'), ['0'])

# %%
# 进行EPR分析
epra = epr.QuantumAnalysis(eprd.data_filename)
epra.analyze_all_variations(cos_trunc = 8, fock_trunc = 7)
# Out:
# WARNING 08:36PM [__init__]: <p>Error: <class 'IndexError'></p>
# 	 Differences in variations:
#
#
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 0
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.021211
# 1    1.022038
# 2    1.026063
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2   Coup
# 0  False   True  False
# 1   True  False  False
# 2  False  False   True
# *** P (participation matrix, not normlz.)
#          Q1        Q2      Coup
# 0  0.000007  0.978726  0.000016
# 1  0.977418  0.000006  0.000035
# 2  0.000034  0.000016  0.954912
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2  s_Coup
# 0     1     1       1
# 1     1     1       1
# 2     1     1       1
# *** P (participation matrix, normalized.)
#    6.5e-06        1  1.6e-05
#          1  6.4e-06  3.5e-05
#    3.4e-05  1.6e-05     0.98
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        200   0.0055   0.0447
#     0.0055      204   0.0703
#     0.0447   0.0703      231
#
# *** Chi matrix ND (MHz)
#        241   0.0478   0.0512
#     0.0478      254   0.0807
#     0.0512   0.0807      247
#
# *** Frequencies O1 PT (MHz)
# 0     944.083425
# 1    1431.645974
# 2    7707.735466
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0     891.481216
# 1    1396.981099
# 2    7700.645772
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# OrderedDict([('0',
#               OrderedDict([('f_0', 0    1144.095852
#                             1    1635.907704
#                             2    7939.152422
#                             Name: 0, dtype: float64),
#                            ('f_1',
#                             0     944.083425
#                             1    1431.645974
#                             2    7707.735466
#                             dtype: float64),
#                            ('f_ND',
#                             0     891.481216
#                             1    1396.981099
#                             2    7700.645772
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1           2
#                             0  199.987348    0.005504    0.044654
#                             1    0.005504  204.223839    0.070279
#                             2    0.044654    0.070279  231.359490),
#                            ('chi_ND',
#                                         0           1           2
#                             0  241.470597    0.047826    0.051203
#                             1    0.047826  253.615120    0.080710
#                             2    0.051203    0.080710  246.803464),
#                            ('ZPF',
#                             array([[1.51206102e-03, 8.36395620e-01, 5.32711833e-04],
#                                    [7.07017607e-01, 2.52181436e-03, 9.37134499e-04],
#                                    [9.04592516e-03, 8.72748729e-03, 3.44919658e-01]])),
#                            ('Pm_normed',
#                             array([[6.53313650e-06, 9.99485740e-01, 1.62180182e-05],
#                                    [9.98957864e-01, 6.35452282e-06, 3.51010865e-05],
#                                    [3.36959225e-05, 1.56826635e-05, 9.79799605e-01]])),
#                            ('Pm_raw',
#                             0    0.000007
#                             1    0.977418
#                             2    0.000034
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.021211
#                             1    1.022038
#                             2    1.026063
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.491884
#                             1    0.483457
#                             2    0.477668
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Cj         0fF
#                             _Lj_C       5nH
#                             _Lj_Q1    100nH
#                             _Lj_Q2    200nH
#                             Name: 0, dtype: object),
#                            ('Ljs',
#                             Q1      1.000000e-07
#                             Q2      2.000000e-07
#                             Coup    5.000000e-09
#                             Name: 0, dtype: float64),
#                            ('Cjs',
#                             Q1      2.000000e-15
#                             Q2      2.000000e-15
#                             Coup    2.000000e-15
#                             Name: 0, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1, 2]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             2    inf
#                             Name: 0, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)]))])

# %% [markdown]
# ## 进行数据分析

# %% [markdown]
# 根据推导结果，cross-Kerr 与 g 的关系为
# $$
# \chi = 2\frac{g^2}{\Delta^2}(E_{C1} + E_{C2})
# $$
# 因此，耦合强度，
# $$
# g = \sqrt{\frac{\Delta^2 \chi}{2(E_{C1}+E_{C2})}}
# $$

# %%
# Coupler 频率穿插在两个 Qubit 之间
Lj1 = [150, 150, 150, 150, 150, 160, 200]
Lj2 = [50, 50, 50, 40, 60, 60, 100]
Ljc = [4, 5, 6, 6, 6, 6, 5]
chi_qq = np.array([0.001974, 0.002233, 0.002146, 0.001286, 0.003180, 0.002779, 0.005504 ])
chi_1c = np.array([0.041481, 0.052880, 0.058564, 0.054916, 0.059962, 0.057651, 0.044654])
chi_2c = np.array([0.095833, 0.115572, 0.136732, 0.163141, 0.116075, 0.118753, 0.070279])
alpha1 = np.array([191.389689, 200.403962, 199.038874, 190.256634, 201.167931, 201.116181, 199.987348 ])
alpha2 = np.array([203.183235, 204.984889, 205.632520, 202.796459, 205.122321 , 207.091652, 204.223839])
alphac = np.array([230.777329, 231.899999, 236.496022, 228.385303, 234.831537, 235.021188, 231.359490])
freq1 = np.array([1292.559457, 1322.669986, 1318.164374, 1288.702682, 1325.214591, 1282.904909, 1144.095852])
freq2 = np.array([2309.936656, 2320.247209, 2323.977735, 2581.595028, 2118.104857, 2128.267181, 1635.907704])
freqc = np.array([8914.704578, 7981.857652, 7311.408718, 7284.981651, 7283.250694, 7295.558195, 7939.152422])

# %% [markdown]
# ### 计算QQ耦合: $g_{12}$

# %%
# 理想频率
freq_ideal_1 = 5000
freq_ideal_2 = 5000
freq_ideal_c = 6000

# %%
delta_12 = np.abs(freq1 - freq2)
g_disp_12 = np.sqrt(((delta_12 + alpha1)*(delta_12 - alpha2) * chi_qq) / (2 * (alpha1 + alpha2)))

# %%
g_disp_12
# Out:
# array([1.56902605, 1.61712427, 1.59885683, 1.62631481, 1.5121303 ,
#        1.5078432 , 1.16384587])

# %%
g_reson_12 = g_disp_12 / np.sqrt(freq1 * freq2) * np.sqrt(freq_ideal_1 * freq_ideal_2)

# %%
g_reson_12
# Out:
# array([4.54019867, 4.61551877, 4.56750272, 4.45814507, 4.51276155,
#        4.56263658, 4.25358257])

# %% [markdown]
# ### 计算 $g_{1c}$

# %%
delta_1c = np.abs(freq1 - freqc)
g_disp_1c = np.sqrt(((delta_1c + alpha1) * (delta_1c - alphac) * chi_1c) / (2 * (alpha1 + alphac)))

# %%
g_disp_1c
# Out:
# array([53.26643639, 51.92770368, 48.95566077, 48.3777277 , 49.23364703,
#        48.71125122, 48.74963456])

# %%
g_idealFreq_1c = g_disp_1c / np.sqrt(freq1 * freqc) * np.sqrt(freq_ideal_1 * freq_ideal_c)

# %%
g_idealFreq_1c
# Out:
# array([85.94795098, 87.53505456, 86.37304452, 86.47996313, 86.79943558,
#        87.20942359, 88.59591878])

# %% [markdown]
# ### 计算 $g_{2c}$

# %%
delta_2c = np.abs(freq2 - freqc)
g_disp_2c = np.sqrt(((delta_2c + alpha2) * (delta_2c - alphac) * chi_2c) / (2 * (alpha2 + alphac)))

# %%
g_disp_2c
# Out:
# array([69.21995877, 64.90964091, 61.76567167, 64.44731521, 59.09980829,
#        59.66620824, 56.45858378])

# %%
g_idealFreq_2c = g_disp_2c / np.sqrt(freq2 * freqc) * np.sqrt(freq_ideal_2 * freq_ideal_c)

# %%
g_idealFreq_2c
# Out:
# array([83.54846023, 82.61344168, 82.07129445, 81.39676938, 82.41577407,
#        82.93669595, 85.80728061])

# %% [markdown]
# ### 计算是否关断

# %%
delta_1c_ideal = freq_ideal_c-freq_ideal_1
delta_2c_ideal = freq_ideal_c-freq_ideal_2
g_eff = g_reson_12 - g_idealFreq_2c*g_idealFreq_1c / 2 * (1/delta_1c_ideal+1/delta_2c_ideal)

# %%
g_eff
# Out:
# array([-2.6406203 , -2.61605336, -2.52124485, -2.58104454, -2.64088112,
#        -2.67022487, -3.34859229])

# %% [markdown]
# 等效电路 Q-Q 结构耦合强度计算公式
# $$
# g = \frac{1}{2} \frac{C_{12}}{\sqrt{(C_{1g}+C_{12})(C_{2g}+C_{12})}}\sqrt{\omega_1 \omega_2}
# $$

# %%
from matplotlib import pyplot as plt

# %%
# g_reson[0:6] = g_reson[0:6]*-1
plt.figure()
plt.plot(freqc[:4], g_reson_12[0:4])
plt.ylim([3, 5])
plt.xlabel('Freq_c')
plt.ylabel('g(MHz)')
plt.show()

# %%
plt.figure()
plt.plot(g_reson_12[4:])
plt.ylim([3, 5])
plt.ylabel('g(MHz)')
plt.ylim([4, 6])
plt.show()

# %% [markdown]
# ## 等效电路方法
#
# $$
# g_{qc} = \frac{1}{2}\frac{C_{qc}}{\sqrt{C_q C_c}}\sqrt{\omega_q \omega_c}
# $$
#
# $$
# g_{12} = \frac{1}{2}\left[ \frac{C_{12}}{\sqrt{C_1 C_2}} + \frac{C_{1c}C_{2c}}{\sqrt{C_1 C_2 C_c^2}} \right ]\sqrt{\omega_q \omega_c}
# $$

# %%
C_1c = 1
C_2c = 1
C_12 = 1
C_1 = 1
C_2 = 1
C_c = 1

# %%
g_1c = (0.5 * C_1c / np.sqrt(C_1 * C_c)) * np.sqrt(freq_ideal_1 * freq_ideal_c)
g_2c = (0.5 * C_2c / np.sqrt(C_2 * C_c)) * np.sqrt(freq_ideal_2 * freq_ideal_c)
g_1c, g_2c
# Out:
# (2738.6127875258308, 2738.6127875258308)

# %%
g_12 = 0.5*((C_12/(np.sqrt(C_1*C_2))) + (C_12 * C_2c/(np.sqrt(C_1*C_2*C_c**2)))) * np.sqrt(freq_ideal_1 * freq_ideal_2)
g_12
# Out:
# 5000.0
