# %% [markdown]
# # EPR 方法验证

# %%
# 导入必要的包
import pyEPR as epr
import numpy as np

# %%
# 与 Ansys 建立连接
pinfo = epr.ProjectInfo(project_path = r'C:\Users\admin\Desktop\QEDA\AnsysProject_ours',  # project 所在的文件夹
                        project_name = r'test-QQcoupling-20220424',  # project 名字
                        design_name  = r'QQ-normal2')  # design 名字
# Out:
# INFO 08:23AM [connect_project]: Connecting to Ansys Desktop API...
# INFO 08:23AM [load_ansys_project]: 	File path to HFSS project found.
# INFO 08:23AM [load_ansys_project]: 	Opened Ansys App
# INFO 08:23AM [load_ansys_project]: 	Opened Ansys Desktop v2021.2.0
# INFO 08:23AM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/admin/Desktop/QEDA/AnsysProject_ours/
# 	Project:   test-QQcoupling-20220424
# INFO 08:23AM [connect_design]: 	Opened active design
# 	Design:    QQ-normal2 [Solution type: Eigenmode]
# INFO 08:23AM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 08:23AM [connect]: 	Connected to project "test-QQcoupling-20220424" and design "QQ-normal2" 😀

# %%
# 指定 juntion 的信息
pinfo.junctions['Q1'] = {'Lj_variable':'Lj1', 'rect':'Lj_1', 'line': 'line1', 'Cj_variable':'Cj'}
pinfo.junctions['Q2'] = {'Lj_variable':'Lj2', 'rect':'Lj_2', 'line': 'line2', 'Cj_variable':'Cj'}
pinfo.validate_junction_info() # Check that valid names of variables and objects have been supplied.

# %%
# 指定耗散部分
pinfo.dissipative['dielectrics_bulk'] = ['Box1']  # []中填写衬底等非理想介质体的名称

# %%
# 开始微波仿真分析(先手动仿真完再运行这一步)
eprd = epr.DistributedAnalysis(pinfo)
# swp_var = 'Lj_Q2' # Sweep variable from optimetric analysis that should be used on the x axis for the frequency plot
# eprd.quick_plot_frequencies(swp_var) # plot the solved frequencies before the analysis
eprd.hfss_report_full_convergence() # report convergen
eprd.do_EPR_analysis()
# Out:
# Design "QQ-normal2" info:
# 	# eigenmodes    2
# 	# variations    5
# INFO 08:24AM [hfss_report_full_convergence]: Creating report for variation 0
# INFO 08:24AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\test-QQcoupling-20220424\QQ-normal2\hfss_eig_f_convergence.csv
# INFO 08:24AM [hfss_report_full_convergence]: Creating report for variation 1
# INFO 08:24AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\test-QQcoupling-20220424\QQ-normal2\hfss_eig_f_convergence.csv
# INFO 08:24AM [hfss_report_full_convergence]: Creating report for variation 2
# INFO 08:24AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\test-QQcoupling-20220424\QQ-normal2\hfss_eig_f_convergence.csv
# INFO 08:24AM [hfss_report_full_convergence]: Creating report for variation 3
# INFO 08:24AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\test-QQcoupling-20220424\QQ-normal2\hfss_eig_f_convergence.csv
# INFO 08:24AM [hfss_report_full_convergence]: Creating report for variation 4
# INFO 08:24AM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\test-QQcoupling-20220424\QQ-normal2\hfss_eig_f_convergence.csv
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 0  [1/5]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 5.01 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.9%  1.791e-27 1.381e-30
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.83%
# 	Q1              0.0035495  (+)        4.21251e-05
# 		Energy fraction (Lj over Lj&Cj)= 95.47%
# 	Q2              0.994645  (+)        0.0472173
# 		(U_tot_cap-U_tot_ind)/mean=2.36%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.9084162457514959
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 10.09 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.7%  1.093e-27 3.495e-30
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 95.40%
# 	Q1              0.992136  (+)        0.0478466
# 		Energy fraction (Lj over Lj&Cj)= 83.83%
# 	Q2              0.00353197  (+)        0.000681329
# 		(U_tot_cap-U_tot_ind)/mean=2.43%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9087676049366677
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 1  [2/5]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 9.12 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.8%  1.278e-27  3.18e-30
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 96.21%
# 	Q1              0.174082  (+)        0.0068586
# 		Energy fraction (Lj over Lj&Cj)= 95.61%
# 	Q2              0.822309  (+)        0.0377975
# 		(U_tot_cap-U_tot_ind)/mean=2.24%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.9087695824154457
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 10.27 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.7%  1.101e-27 3.767e-30
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 95.24%
# 	Q1              0.821597  (+)        0.0410643
# 		Energy fraction (Lj over Lj&Cj)= 94.49%
# 	Q2               0.17385  (+)        0.0101374
# 		(U_tot_cap-U_tot_ind)/mean=2.55%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9087962220954995
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 2  [3/5]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 8.59 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.8%  1.807e-27 4.039e-30
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 96.62%
# 	Q1              0.0755736  (+)        0.00264413
# 		Energy fraction (Lj over Lj&Cj)= 95.54%
# 	Q2              0.921444  (+)        0.0429853
# 		(U_tot_cap-U_tot_ind)/mean=2.27%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.9086669691935361
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 10.19 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.7%  1.021e-27 3.392e-30
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 95.32%
# 	Q1              0.920113  (+)        0.0452248
# 		Energy fraction (Lj over Lj&Cj)= 93.85%
# 	Q2              0.0754607  (+)        0.00494532
# 		(U_tot_cap-U_tot_ind)/mean=2.50%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9087044657449657
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 3  [4/5]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 7.07 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.8%  1.949e-27 2.984e-30
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 97.69%
# 	Q1              0.0154274  (+)        0.00036494
# 		Energy fraction (Lj over Lj&Cj)= 95.48%
# 	Q2              0.981972  (+)        0.0464578
# 		(U_tot_cap-U_tot_ind)/mean=2.34%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.9086177540139538
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 10.12 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.7%  1.275e-27 4.122e-30
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 95.38%
# 	Q1              0.980257  (+)        0.0475288
# 		Energy fraction (Lj over Lj&Cj)= 91.16%
# 	Q2              0.0153753  (+)        0.00149097
# 		(U_tot_cap-U_tot_ind)/mean=2.45%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.9087856875830217
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 4  [5/5]
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1096: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1097: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 5.78 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.9%  9.014e-28 9.276e-31
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 98.44%
# 	Q1              0.0059823  (+)        9.47712e-05
# 		Energy fraction (Lj over Lj&Cj)= 95.46%
# 	Q2              0.991946  (+)        0.047143
# 		(U_tot_cap-U_tot_ind)/mean=2.36%
# Calculating Qdielectric_Box1 for mode 0 (0/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_0 = 0.9085790807941412
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1240: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 10.10 GHz   [2/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.7%  3.708e-28 1.193e-30
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:976: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 95.39%
# 	Q1              0.990178  (+)        0.0478864
# 		Energy fraction (Lj over Lj&Cj)= 87.33%
# 	Q2              0.00595283  (+)        0.000863663
# 		(U_tot_cap-U_tot_ind)/mean=2.41%
# Calculating Qdielectric_Box1 for mode 1 (1/1)
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:928: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# p_dielectric_Box1_1 = 0.908851920958262
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_distributed_analysis.py:1302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# ANALYSIS DONE. Data saved to:
#
# C:\data-pyEPR\test-QQcoupling-20220424\QQ-normal2\2022-04-28 08-24-03.npz
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# (WindowsPath('C:/data-pyEPR/test-QQcoupling-20220424/QQ-normal2/2022-04-28 08-24-03.npz'),
#  ['0', '1', '2', '3', '4'])

# %%
# 进行EPR分析
epra = epr.QuantumAnalysis(eprd.data_filename)
epra.analyze_all_variations(cos_trunc = 8, fock_trunc = 7)
# Out:
# 	 Differences in variations:
# variation     0    1    2     3     4
# _Lj2       24nH  7nH  8nH  12nH  18nH
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 0
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.048363
# 1    1.049802
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0  False   True
# 1   True  False
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj2    24nH
# Name: 0, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.003389  0.949760
# 1  0.946218  0.003369
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#     0.0034        1
#       0.99   0.0034
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        456     7.78
#       7.78      461
#
# *** Chi matrix ND (MHz)
#        554     12.4
#       12.4      510
#
# *** Frequencies O1 PT (MHz)
# 0    4545.432278
# 1    9624.713021
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    4490.586013
# 1    9600.358785
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 1
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.045887
# 1    1.052484
# dtype: float64
#
# Pm_norm idx =
#      Q1    Q2
# 0  True  True
# 1  True  True
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj2    7nH
# Name: 1, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.166641  0.787157
# 1  0.781579  0.165382
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#       0.17     0.82
#       0.82     0.17
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        313      267
#        267      345
#
# *** Chi matrix ND (MHz)
#        832      311
#        311      130
#
# *** Frequencies O1 PT (MHz)
# 0    8672.683781
# 1    9793.318898
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    8478.281951
# 1    9861.659486
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 2
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.046464
# 1    1.051417
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0  False   True
# 1   True  False
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj2    8nH
# Name: 2, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.072276  0.881234
# 1  0.876156  0.071856
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#      0.072     0.92
#       0.92    0.072
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        386      124
#        124      407
#
# *** Chi matrix ND (MHz)
#        565      222
#        222      323
#
# *** Frequencies O1 PT (MHz)
# 0    8145.585651
# 1    9716.367005
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    8060.293269
# 1    9720.782097
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 3
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.047981
# 1    1.050295
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0  False   True
# 1   True  False
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj2    12nH
# Name: 3, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.014737  0.938050
# 1  0.934450  0.014657
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#      0.015     0.98
#       0.98    0.015
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        443     28.4
#       28.4      453
#
# *** Chi matrix ND (MHz)
#        528     45.1
#       45.1      489
#
# *** Frequencies O1 PT (MHz)
# 0    6609.271303
# 1    9649.950365
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    6566.150162
# 1    9627.568294
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 4
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.048357
# 1    1.049516
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2
# 0  False   True
# 1   True  False
#
# *** Different parameters
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:715: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\core_quantum_analysis.py:720: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# _Lj2    18nH
# Name: 4, dtype: object
# *** P (participation matrix, not normlz.)
#          Q1        Q2
# 0  0.005712  0.947202
# 1  0.944150  0.005676
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2
# 0     1     1
# 1     1     1
# *** P (participation matrix, normalized.)
#     0.0057     0.99
#       0.99   0.0057
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        454     12.1
#       12.1      460
#
# *** Chi matrix ND (MHz)
#        544     18.3
#       18.3      507
#
# *** Frequencies O1 PT (MHz)
# 0    5322.808495
# 1    9637.675326
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    5275.232072
# 1    9613.548157
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
# OrderedDict([('0',
#               OrderedDict([('f_0', 0     5005.136967
#                             1    10089.496479
#                             Name: 0, dtype: float64),
#                            ('f_1',
#                             0    4545.432278
#                             1    9624.713021
#                             dtype: float64),
#                            ('f_ND',
#                             0    4490.586013
#                             1    9600.358785
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  455.816083    7.777214
#                             1    7.777214  460.894850),
#                            ('chi_ND',
#                                         0           1
#                             0  553.619500   12.431749
#                             1   12.431749  509.629124),
#                            ('ZPF',
#                             array([[0.01764483, 0.60485814],
#                                    [0.42888109, 0.04995008]])),
#                            ('Pm_normed',
#                             array([[0.00338933, 0.99569278],
#                                    [0.99334148, 0.0033685 ]])),
#                            ('Pm_raw',
#                             0    0.003389
#                             1    0.946218
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.048363
#                             1    1.049802
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.500601
#                             1    0.500140
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Lj1            6nH
#                             _Lj2           24nH
#                             _Lj_right       6nH
#                             _x_leftQ      -50um
#                             _x_rightQ      50um
#                             _y_leftQ     -101um
#                             _y_rightQ     101um
#                             Name: 0, dtype: object),
#                            ('Ljs',
#                             Q1    6.000000e-09
#                             Q2    2.400000e-08
#                             Name: 0, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 0, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 0, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('1',
#               OrderedDict([('f_0', 0     9119.479213
#                             1    10271.456589
#                             Name: 1, dtype: float64),
#                            ('f_1',
#                             0    8672.683781
#                             1    9793.318898
#                             dtype: float64),
#                            ('f_ND',
#                             0    8478.281951
#                             1    9861.659486
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  313.325314  266.940237
#                             1  266.940237  344.667572),
#                            ('chi_ND',
#                                         0           1
#                             0  831.526625  311.468091
#                             1  311.468091  130.203824),
#                            ('ZPF',
#                             array([[0.1707933 , 0.40094457],
#                                    [0.39378863, 0.19565637]])),
#                            ('Pm_normed',
#                             array([[0.17428736, 0.82327724],
#                                    [0.82259973, 0.17406178]])),
#                            ('Pm_raw',
#                             0    0.166641
#                             1    0.781579
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.045887
#                             1    1.052484
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.498373
#                             1    0.501437
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Lj1            6nH
#                             _Lj2            7nH
#                             _Lj_right       6nH
#                             _x_leftQ      -50um
#                             _x_rightQ      50um
#                             _y_leftQ     -101um
#                             _y_rightQ     101um
#                             Name: 1, dtype: object),
#                            ('Ljs',
#                             Q1    6.000000e-09
#                             Q2    7.000000e-09
#                             Name: 1, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 1, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 1, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('2',
#               OrderedDict([('f_0', 0     8593.808145
#                             1    10185.843702
#                             Name: 2, dtype: float64),
#                            ('f_1',
#                             0    8145.585651
#                             1    9716.367005
#                             dtype: float64),
#                            ('f_ND',
#                             0    8060.293269
#                             1    9720.782097
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  385.996564  124.451860
#                             1  124.451860  407.250767),
#                            ('chi_ND',
#                                         0           1
#                             0  564.517063  222.096595
#                             1  222.096595  322.788747),
#                            ('ZPF',
#                             array([[0.1067682 , 0.44037528],
#                                    [0.4149824 , 0.13382935]])),
#                            ('Pm_normed',
#                             array([[0.07227572, 0.92218007],
#                                    [0.92120567, 0.0718557 ]])),
#                            ('Pm_raw',
#                             0    0.072276
#                             1    0.876156
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.046464
#                             1    1.051417
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.502967
#                             1    0.501249
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Lj1            6nH
#                             _Lj2            8nH
#                             _Lj_right       6nH
#                             _x_leftQ      -50um
#                             _x_rightQ      50um
#                             _y_leftQ     -101um
#                             _y_rightQ     101um
#                             Name: 2, dtype: object),
#                            ('Ljs',
#                             Q1    6.000000e-09
#                             Q2    8.000000e-09
#                             Name: 2, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 2, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 2, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('3',
#               OrderedDict([('f_0', 0     7066.332665
#                             1    10116.679798
#                             Name: 3, dtype: float64),
#                            ('f_1',
#                             0    6609.271303
#                             1    9649.950365
#                             dtype: float64),
#                            ('f_ND',
#                             0    6566.150162
#                             1    9627.568294
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  442.865081   28.392561
#                             1   28.392561  452.533153),
#                            ('chi_ND',
#                                         0           1
#                             0  528.173200   45.089829
#                             1   45.089829  488.884002),
#                            ('ZPF',
#                             array([[0.04371794, 0.50495723],
#                                    [0.42687981, 0.07377454]])),
#                            ('Pm_normed',
#                             array([[0.01473735, 0.98305851],
#                                    [0.98144843, 0.0146568 ]])),
#                            ('Pm_raw',
#                             0    0.014737
#                             1    0.934450
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.047981
#                             1    1.050295
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.500021
#                             1    0.500386
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Lj1            6nH
#                             _Lj2           12nH
#                             _Lj_right       6nH
#                             _x_leftQ      -50um
#                             _x_rightQ      50um
#                             _y_leftQ     -101um
#                             _y_rightQ     101um
#                             Name: 3, dtype: object),
#                            ('Ljs',
#                             Q1    6.000000e-09
#                             Q2    1.200000e-08
#                             Name: 3, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 3, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 3, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)])),
#              ('4',
#               OrderedDict([('f_0', 0     5782.740391
#                             1    10103.671689
#                             Name: 4, dtype: float64),
#                            ('f_1',
#                             0    5322.808495
#                             1    9637.675326
#                             dtype: float64),
#                            ('f_ND',
#                             0    5275.232072
#                             1    9613.548157
#                             dtype: float64),
#                            ('chi_O1',
#                                         0           1
#                             0  453.881482   12.100829
#                             1   12.100829  459.945949),
#                            ('chi_ND',
#                                         0           1
#                             0  543.734611   18.346749
#                             1   18.346749  507.164360),
#                            ('ZPF',
#                             array([[0.02462244, 0.56228457],
#                                    [0.42865456, 0.05619258]])),
#                            ('Pm_normed',
#                             array([[0.00571246, 0.99300547],
#                                    [0.99090022, 0.00567612]])),
#                            ('Pm_raw',
#                             0    0.005712
#                             1    0.944150
#                             Name: Q1, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.048357
#                             1    1.049516
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.500499
#                             1    0.505217
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Lj1            6nH
#                             _Lj2           18nH
#                             _Lj_right       6nH
#                             _x_leftQ      -50um
#                             _x_rightQ      50um
#                             _y_leftQ     -101um
#                             _y_rightQ     101um
#                             Name: 4, dtype: object),
#                            ('Ljs',
#                             Q1    6.000000e-09
#                             Q2    1.800000e-08
#                             Name: 4, dtype: float64),
#                            ('Cjs',
#                             Q1    2.000000e-15
#                             Q2    2.000000e-15
#                             Name: 4, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 4, dtype: float64),
#                            ('fock_trunc', 7),
#                            ('cos_trunc', 8)]))])

# %% [markdown]
# ## 进行数据分析

# %% [markdown]
# 根据推导结果，cross-Kerr 与 g 的关系为
# $$
# \chi = 2\frac{g^2}{\Delta^2}(E_{C1} + E_{C2})
# $$
# 因此，耦合强度，
# $$
# g = \sqrt{\frac{\Delta^2 \chi}{2(E_{C1}+E_{C2})}}
# $$

# %%
# 左：6nH，右：[7, 12, 18, 24, 7, 8, 12, 18, 24_正义]
chi = np.array([267.918496, 28.652446, 11.531974, 7.777214, 266.940237, 124.451860, 28.392561, 12.100829, 7.75715])
freq1 = np.array([9124.898599, 7074.60667, 5746.025491, 5005.136967, 9119.479213, 8593.808145, 7066.332665, 5782.740391, 4970.2])
freq2 = np.array([10278.238012, 10125.92544, 10047.305092, 10089.496479, 10271.456589, 10185.843702, 10116.679798, 10103.671689, 10029.93])

freq1_bare = np.array([9124.898599, 7079.22, 5763.2, 4991.1])
freq2_bare = np.array([10278.238012, 9998.6, 9977.2, 9987.9])

alpha1 = np.array([313.374411, 443.798046, 448.345418, 455.816083, 313.325314, 385.996564, 442.865081, 453.881482, 449])
alpha2 = np.array([344.791385, 453.253899, 455.062177, 460.894850, 344.667572, 407.250767, 452.533153, 459.945949, 455])

# %%
delta = np.abs(freq1 - freq2)
g_disp = np.sqrt(((delta ** 2) * chi) / (2 * (alpha1 + alpha2)))
# g_disp = np.sqrt((((delta - alpha1) *(delta-alpha2)) * chi) / (2 * (alpha1 + alpha2)))

# %%
g_disp
# Out:
# array([520.32636167, 385.60675927, 343.63123675, 331.14413919,
#        518.83035097, 445.89659038, 384.08596215, 351.5910652 ,
#        331.42039003])

# %%
g_reson = g_disp / np.sqrt(freq1 * freq2) * np.sqrt(10271.456589 * 9119.479213)  # 6,7nH
g_reson = g_disp / np.sqrt(freq1 * freq2) * 10125.92544  # 6,6nH
# g_reson = g_disp / np.sqrt(freq1 * freq2) * np.sqrt(10185.843702 * 8593.808145)  # 6,8nH

# %%
g_reson
# Out:
# array([544.04797225, 461.32910091, 457.95076751, 471.85555086,
#        542.8240272 , 482.58914149, 459.98865238, 465.76418956,
#        475.31121954])

# %% [markdown]
# ### 错误公式验证

# %% [markdown]
# 错误公式，
# $$
# \chi = \frac{g^2}{\Delta}
# $$
# 因此，耦合强度
# $$
# g = \sqrt{\chi \Delta}
# $$

# %%
delta = np.abs(freq1 - freq2)
g_disp_error = np.sqrt(chi * delta)

# %%
g_disp_error
# Out:
# array([3.21262966, 2.73477559, 2.25907293, 2.15154061, 2.00057918,
#        1.85370052, 1.77478001])

# %%
g_reson_error = g_disp_error / np.sqrt(freq1 * freq2) * freq2

# %%
g_reson_error
# Out:
# array([3.63841068, 3.27266965, 2.84680418, 2.80958476, 2.69917774,
#        2.57855665, 2.55295739])

# %% [markdown]
# ### Q3D + 等效电路检验

# %%
C_1g = 0.08946
C_2g = 0.08923
C_12 = 0.00013

# %% [markdown]
# 等效电路 Q-Q 结构耦合强度计算公式
# $$
# g = \frac{1}{2} \frac{C_{12}}{\sqrt{(C_{1g}+C_{12})(C_{2g}+C_{12})}}\sqrt{\omega_1 \omega_2}
# $$

# %%
# 耦合强度除掉频率项后的无量纲部分
g_effCirc_dimless =  0.5 * C_12 / np.sqrt((C_1g + C_12) * (C_2g + C_12))

# %%
g_effCirc_dimless
# Out:
# 0.0007264605050334611

# %%
# 等效电路下的耦合强度
g_effCirc = g_effCirc_dimless * np.sqrt(4961 * 4926)
g_effCirc
# Out:
# 3.5912350044354158
