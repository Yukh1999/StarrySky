# %%
import pyEPR as epr

# %%
# 与Ansys建立连接
pinfo = epr.ProjectInfo(project_path = r'C:\Users\admin\Documents\Ansoft',  # project 所在的文件夹
                        project_name = r'Project1',  # project 名字
                        design_name  = r'MIT_QCQ')  # design 名字
# Out:
# INFO 04:08PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 04:08PM [load_ansys_project]: 	File path to HFSS project found.
# INFO 04:08PM [load_ansys_project]: 	Opened Ansys App
# INFO 04:08PM [load_ansys_project]: 	Opened Ansys Desktop v2021.2.0
# INFO 04:08PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/admin/Documents/Ansoft/
# 	Project:   Project1
# INFO 04:08PM [connect_design]: 	Opened active design
# 	Design:    MIT_QCQ [Solution type: Eigenmode]
# INFO 04:08PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 04:08PM [connect]: 	Connected to project "Project1" and design "MIT_QCQ" 😀

# %%
# 指定 juntion 的信息
pinfo.junctions['Q1'] = {'Lj_variable':'Q1_Lj', 'rect':'JJ_rect_Lj_Q1_rect_jj', 'line': 'JJ_Lj_Q1_rect_jj_', 'Cj_variable':'Cj'}
pinfo.junctions['Q2'] = {'Lj_variable':'Q2_Lj', 'rect':'JJ_rect_Lj_Q2_rect_jj', 'line': 'JJ_Lj_Q2_rect_jj_', 'Cj_variable':'Cj'}
pinfo.junctions['Coup'] = {'Lj_variable':'Coup_Lj', 'rect':'JJ_rect_Lj_Tune_C_Q12_rect_jj', 'line': 'JJ_Lj_Tune_C_Q12_rect_jj_', 'Cj_variable':'Cj'}
pinfo.validate_junction_info() # Check that valid names of variables and objects have been supplied.

# %%
# 指定耗散部分
pinfo.dissipative['dielectrics_bulk']    = ['main']  # []中填写衬底等非理想介质体的名称

# %%
# 开始微波仿真分析(先手动仿真完再运行这一步)
eprd = epr.DistributedAnalysis(pinfo)
swp_var = 'Q1_Lj' # Sweep variable from optimetric analysis that should be used on the x axis for the frequency plot
eprd.quick_plot_frequencies(swp_var) # plot the solved frequencies before the analysis
eprd.hfss_report_full_convergence() # report convergen
eprd.do_EPR_analysis()
# Out:
# Design "MIT_QCQ" info:
# 	# eigenmodes    3
# 	# variations    1
# INFO 04:22PM [hfss_report_full_convergence]: Creating report for variation 0
# INFO 04:22PM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\Project1\MIT_QCQ\hfss_eig_f_convergence.csv
# ERROR 04:22PM [hfss_report_f_convergence]: Error could not save and export hfss plot to C:\data-pyEPR\Project1\MIT_QCQ\hfss_eig_f_convergence.csv.                               Is the plot made in HFSS with the correct name.                               Check the HFSS error window. 	 Error =  [Errno 2] No such file or directory: 'C:\\data-pyEPR\\Project1\\MIT_QCQ\\hfss_eig_f_convergence.csv'
# D:\Anaconda\envs\QEDA\lib\site-packages\pyEPR\project_info.py:226: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 0  [1/1]
# ...

# %%
# 进行EPR分析
epra = epr.QuantumAnalysis(eprd.data_filename)
epra.analyze_all_variations(cos_trunc = 8, fock_trunc = 7)
# Out:
# WARNING 04:22PM [__init__]: <p>Error: <class 'IndexError'></p>
# 	 Differences in variations:
#
#
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 0
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.014632
# 1    1.017180
# 2    1.017325
# dtype: float64
#
# Pm_norm idx =
#       Q1     Q2   Coup
# 0  False  False   True
# 1   True   True  False
# 2   True   True  False
# *** P (participation matrix, not normlz.)
#          Q1        Q2      Coup
# 0  0.002413  0.002443  0.975936
# 1  0.600411  0.372882  0.000061
# 2  0.370697  0.597794  0.004800
#
# *** S (sign-bit matrix)
#    s_Q1  s_Q2  s_Coup
# 0     1     1       1
# 1     1     1       1
# 2     1     1       1
# *** P (participation matrix, normalized.)
#     0.0024   0.0024     0.99
#       0.61     0.38  6.1e-05
#       0.38     0.61   0.0048
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
# ...

# %%
# 结果
swp_variable = 'Q1_Lj'
epra.plot_hamiltonian_results(swp_variable=swp_variable)
epra.report_results(swp_variable=swp_variable, numeric=True)
epra.quick_plot_mode(0,0,1,numeric=True, swp_variable=swp_variable)
# Out:
# #### Mode frequencies (MHz)
# ###### Numerical diagonalization
# Q1_Lj       10
# 0      3250.39
# 1      4287.25
# 2      4645.28
# #### Kerr Non-linear coefficient table (MHz)
# ###### Numerical diagonalization
#               0       1       2
# Q1_Lj
# 10    0  141.99    8.16    0.63
#       1    8.16 -349.85 -358.10
#       2    0.63 -358.10  366.20
